# %% [markdown]
# # Pulling APFS Records from apfs.dhs.gov

# %%
import numpy as np
import pandas as pd
import os
import requests
from bs4 import BeautifulSoup as bs
from splinter import Browser
import time
import csv
from datetime import datetime
import glob

# %%
# Get current date in variable

today = datetime.today()
today_string = today.strftime("%d-%b-%Y")

# %%
# Save previous APFS pull in variable called 'prior_pull'

for f in glob.glob('Current_APFS.csv'):
    prior_pull = pd.read_csv(f)
    
prior_pull.to_csv('archive/APFS_Refreshed' + '_' + today_string + '.csv', index=False)
prior_pull.to_csv('Prior_APFS.csv')

# %%
# Scrape data from APFS store in variable called 'data'

url = "https://apfs.dhs.gov/forecast/?text_search=&component=217&imcf_form_component=forecast-filter&imcf_label_component=&contract_status=&contract_vehicle=&dollar_range=&imcf_form_naicscodes=forecast-filter&imcf_label_naicscodes=&small_business_program=&apfs_number=&page=1&filter_hidden=no&action=csv&page_select=-1"

raw_pull = requests.get(url)
separated_pull = raw_pull.text.split('\n')
data = []

for line in separated_pull:
    string = line
    for entry in csv.reader([string], skipinitialspace=True):
        data.append(entry)

# %%
# Import 'data' into a pandas dataframe and clean it up

df = pd.DataFrame(data)

header_row = 0
df.columns = df.iloc[header_row]
df = df.drop(header_row)
df = df.iloc[:-1]
df = df.reset_index(drop=True)

for row in df:
    df['Last Recorded on APFS'] = today_string

df.to_csv('Current_APFS.csv', index=False)

# %% [markdown]
# # Identifying added opportunities

# %%
# Check to see what APFS numbers in df dataframe are not present in prior_pull dataframe
# Store rows with new APFS numbers in their own dataframe
# Send alert

#Get APFS Numbers of the current APFS listing. Save them as 'today_ids'

today_df = pd.read_csv('Current_APFS.csv')
today_df = today_df.fillna('Not provided')
today_ids = pd.DataFrame(today_df[('APFS Number')])
today_df
# Out:
#     APFS Number                                        Description  \
# 0   F2015026262  In accordance with the National Flood Insuranc...
# 1   F2019045200  The primary functions to be performed for the ...
# 2   F2019045532  The requirement is for commercial-off-the-shel...
# 3   F2019045903  FEMA is seeking a transactional solution for a...
# 4   F2019046930  Under this requirement, the awardee shall have...
# ..          ...                                                ...
# 69  F2020050942  The purpose of this requirement is to pre-posi...
# 70  F2020050972  Enhancement of the AHIMT program by developing...
# 71  F2020050982  FEMA requires architect and engineering servic...
# 72  F2020051045  (12) Shelter Systems to include all the necess...
# 73  F2020051059  Human Capital Software Licenses for FedHR Navi...
#
#    Contract Status Component  NAICS code Small Business Program  \
# 0              NEW      FEMA      541690                   None
# 1              REC      FEMA      562211                     SB
# 2              REC      FEMA      321991                     SB
# 3              REC      FEMA      561990                   None
# 4              REC      FEMA      524292                   None
# ..             ...       ...         ...                    ...
# 69             REC      FEMA      221310                     SB
# 70             REC      FEMA      611430                   8(a)
# 71             NEW      FEMA      541330                     SB
# 72             NEW      FEMA      314910                   None
# 73             REC      FEMA      541612                   WOSB
#
#                         Dollar Range Contract Vehicle  \
# 0     $2,000,000.00 to $5,000,000.00         Contract
# 1   $10,000,000.00 to $20,000,000.00         Contract
# 2               Over $100,000,000.00         Contract
# 3    $5,000,000.00 to $10,000,000.00              GSA
# 4               Over $100,000,000.00         Contract
# ..                               ...              ...
# 69      $500,000.00 to $1,000,000.00            Order
# 70      $500,000.00 to $1,000,000.00         Contract
# 71              Over $100,000,000.00         Contract
# 72      $500,000.00 to $1,000,000.00              GSA
# 73      $500,000.00 to $1,000,000.00              GSA
#
#                                            Contractor  \
# 0                                        Not provided
# 1         TET Consulting Business Management Services
# 2   American Homestar Corporation, Champion Home B...
# 3                                     CoreLogic, Inc.
# 4                                Torrent Technologies
# ..                                                ...
# 69                                      Ready America
# 70                      Solution Guidance Corporation
# 71                                       Not provided
# 72                                       Not provided
# 73                            Economic Systems, Inc.
#
#                                       Contract Number Contract Complete  \
# 0                                        Not provided        2016-09-30
# 1                                    HSFE20-15-C-0169        2025-07-15
# 2   HSFE70-14-D-0149, -0150, -0151, -0152, -0153, ...        2025-06-28
# 3                                    HSFE80-14-A-0031        2019-08-01
# 4                                    HSFE60-16-D-0201        2025-09-30
# ..                                                ...               ...
# 69                                   HSFE70-17-D-0020        2020-06-22
# 70                                  70FA2019P00000048        2025-06-06
# 71                                       Not provided        2026-02-28
# 72                                       Not provided        2020-08-31
# 73                                       GS-02F-0092T        2021-07-14
#
#    Estimated Release Anticipated Award Quarter            POC Name  \
# 0         2015-05-15                   Q4 2020       Barry  Taylor
# 1         2019-11-19                   Q4 2020         Gary Topper
# 2         2020-04-03                   Q3 2020          Erik Young
# 3         2019-06-10                   Q4 2024       Jared Krieger
# 4         2020-06-15                   Q4 2020           Liz Kirby
# ..               ...                       ...                 ...
# 69        2020-06-10                   Q3 2020      Chris Ferguson
# 70        2020-07-01                   Q4 2020      Gregory Keller
# 71        2020-08-31                   Q2 2021  William Sanfilippo
# 72        2020-06-19                   Q3 2020        Randy Warren
# 73        2020-06-18                   Q4 2020   Carol Anne Snider
#
#        POC Phone                        POC Email Last Recorded on APFS
# 0   202-646-3023        Barry.Taylor@fema.dhs.gov           19-Jun-2020
# 1     3014477280         gary.topper@fema.dhs.gov           19-Jun-2020
# 2   202-212-4108          erik.young@fema.dhs.gov           19-Jun-2020
# 3     9402937492       jared.krieger@fema.dhs.gov           19-Jun-2020
# 4   202-212-1802     elizabeth.kirby@fema.dhs.gov           19-Jun-2020
# ..           ...                              ...                   ...
# 69    2022122509      Chris.ferguson@fema.dhs.gov           19-Jun-2020
# 70  301-447-1077      Gregory.Keller@fema.dhs.gov           19-Jun-2020
# 71    2022127135  william.sanfilippo@fema.dhs.gov           19-Jun-2020
# 72  202-304-XXXX        Randy.Warren@fema.dhs.gov           19-Jun-2020
# 73    2022122250    carolanne.snider@fema.dhs.gov           19-Jun-2020
#
# [74 rows x 17 columns]

# %%
#Get APFS Numbers of the previous APFS listing. Save them as 'old_ids'

old_df = pd.read_csv('Prior_APFS.csv')
old_df = old_df.fillna('Not provided')
old_ids = pd.DataFrame(old_df[('APFS Number')])
old_ids
# Out:
#     APFS Number
# 0   F2019046845
# 1   F2019048087
# 2   F2020048899
# 3   F2020048969
# 4   F2020049267
# 5   F2020049269
# 6   F2020049846
# 7   F2020049880
# 8   F2020050067
# 9   F2020050098
# 10  F2020050206
# 11  F2020050310
# 12  F2020050379
# 13  F2020050402
# 14  F2020050424
# 15  F2020050437
# 16  F2020050657
# 17  F2020050675
# 18  F2020050779
# 19  F2020050881
# 20  F2020050908
# 21  F2020050914
# 22  F2020050991
# 23  F2020051041

# %%
# Do a left merge on today_ids with old_ids. Save the dataframe as df_merged_ids

df_merged_ids = today_ids.merge(old_ids, on=['APFS Number'], 
                   how='left', indicator=True)
df_merged_ids
# Out:
#     APFS Number     _merge
# 0   F2015026262  left_only
# 1   F2019045200  left_only
# 2   F2019045532  left_only
# 3   F2019045903  left_only
# 4   F2019046930  left_only
# ..          ...        ...
# 69  F2020050942  left_only
# 70  F2020050972  left_only
# 71  F2020050982  left_only
# 72  F2020051045  left_only
# 73  F2020051059  left_only
#
# [74 rows x 2 columns]

# %%
# APFS Numbers in df_new_ids that have the value 'left_only' for '_merge' are the new IDs. Drop the others and save as df_new_ids

df_new_ids = df_merged_ids[~df_merged_ids['_merge'].isin(['both'])]
df_new_ids
# Out:
#     APFS Number     _merge
# 0   F2015026262  left_only
# 1   F2019045200  left_only
# 2   F2019045532  left_only
# 3   F2019045903  left_only
# 4   F2019046930  left_only
# ..          ...        ...
# 69  F2020050942  left_only
# 70  F2020050972  left_only
# 71  F2020050982  left_only
# 72  F2020051045  left_only
# 73  F2020051059  left_only
#
# [74 rows x 2 columns]

# %%
# Merge our today_df with df_new_ids to get all information on new APFS numbers

new_today_df = df_new_ids.merge(today_df, on=['APFS Number'], 
                   how='left')
del new_today_df['_merge']
new_today_df
new_today_df.to_csv('added/Opportunities_added' + '_' + today_string + '.csv', index=False)

# %%
# Get just the APFS Numbers and descriptions for the opportunities to be able to send in email

new_today_summary = new_today_df[['APFS Number', 'Description']]
new_today_summary = new_today_summary.set_index('APFS Number')
new_today_summary
# Out:
#                                                    Description
# APFS Number
# F2015026262  In accordance with the National Flood Insuranc...
# F2019045200  The primary functions to be performed for the ...
# F2019045532  The requirement is for commercial-off-the-shel...
# F2019045903  FEMA is seeking a transactional solution for a...
# F2019046930  Under this requirement, the awardee shall have...
# ...                                                        ...
# F2020050942  The purpose of this requirement is to pre-posi...
# F2020050972  Enhancement of the AHIMT program by developing...
# F2020050982  FEMA requires architect and engineering servic...
# F2020051045  (12) Shelter Systems to include all the necess...
# F2020051059  Human Capital Software Licenses for FedHR Navi...
#
# [74 rows x 1 columns]

# %% [markdown]
# # Identifying removed opportunities

# %%
# Check to see what APFS numbers in prior_pull dataframe are not present in Current_APFS dataframe
# Store rows with new APFS numbers in their own dataframe
# Send alert

# %%
# Do a left merge on old_ids with today_ids. Save the dataframe as df_merged_ids

df_merged_removed_ids = old_ids.merge(today_ids, on=['APFS Number'], 
                   how='left', indicator=True)
df_merged_removed_ids
# Out:
#     APFS Number     _merge
# 0   F2019046845  left_only
# 1   F2019048087  left_only
# 2   F2020048899  left_only
# 3   F2020048969  left_only
# 4   F2020049267  left_only
# 5   F2020049269  left_only
# 6   F2020049846  left_only
# 7   F2020049880  left_only
# 8   F2020050067  left_only
# 9   F2020050098  left_only
# 10  F2020050206  left_only
# 11  F2020050310  left_only
# 12  F2020050379  left_only
# 13  F2020050402  left_only
# 14  F2020050424  left_only
# 15  F2020050437  left_only
# 16  F2020050657  left_only
# 17  F2020050675  left_only
# 18  F2020050779  left_only
# 19  F2020050881  left_only
# 20  F2020050908  left_only
# 21  F2020050914  left_only
# 22  F2020050991  left_only
# 23  F2020051041  left_only

# %%
# APFS Numbers in df_old_ids that have the value 'left_only' for '_merge' are the old IDs. Drop the others and save as df_old_ids

df_old_ids = df_merged_removed_ids[~df_merged_removed_ids['_merge'].isin(['both'])]
df_old_ids
# Out:
#     APFS Number     _merge
# 0   F2019046845  left_only
# 1   F2019048087  left_only
# 2   F2020048899  left_only
# 3   F2020048969  left_only
# 4   F2020049267  left_only
# 5   F2020049269  left_only
# 6   F2020049846  left_only
# 7   F2020049880  left_only
# 8   F2020050067  left_only
# 9   F2020050098  left_only
# 10  F2020050206  left_only
# 11  F2020050310  left_only
# 12  F2020050379  left_only
# 13  F2020050402  left_only
# 14  F2020050424  left_only
# 15  F2020050437  left_only
# 16  F2020050657  left_only
# 17  F2020050675  left_only
# 18  F2020050779  left_only
# 19  F2020050881  left_only
# 20  F2020050908  left_only
# 21  F2020050914  left_only
# 22  F2020050991  left_only
# 23  F2020051041  left_only

# %%
# Merge our old_df with df_old_ids to get all information on new APFS numbers

removed_today_df = df_old_ids.merge(old_df, on=['APFS Number'], 
                   how='left')
del removed_today_df['_merge']
removed_today_df.to_csv('removed/Opportunities_removed' + '_' + today_string + '.csv', index=False)

# %%
removed_today_summary = removed_today_df[['APFS Number', 'Description']]
removed_today_summary = removed_today_summary.set_index('APFS Number')
removed_today_summary
# Out:
#                                                    Description
# APFS Number
# F2019046845  The Department of Homeland Security (DHS), U.S...
# F2019048087  OFA requires dedicated full-time individuals t...
# F2020048899  ODO and ERAU require contractor support for co...
# F2020048969  Provide SEVP with Design, Development, Test, D...
# F2020049267  IHSC is seeking to procure a coordinated, comp...
# F2020049269  The scope of this effort includes employing pr...
# F2020049846  The scope of this effort is to perform Agile s...
# F2020049880  Provides SEVP Technical PMO support in the are...
# F2020050067  The Government is seeking for a Contractor to ...
# F2020050098  U.S. Immigration and Customs Enforcement (ICE)...
# F2020050206  The scope of work under this requirement is to...
# F2020050310  ICE requires all applications to be maintained...
# F2020050379  The Hybrid ESPC ENABLE procurement process use...
# F2020050402  The Contractor shall furnish a turnkey solutio...
# F2020050424  The IHSC is seeking contract support services ...
# F2020050437  This requirement is to procure non-personal se...
# F2020050657  ICE/HSI requires software/hardware upgrades to...
# F2020050675  HSI is seeking to use a commercially available...
# F2020050779  It is a requirement of the U.S. Immigration an...
# F2020050881  The Contractor shall provide data management s...
# F2020050908  This requirement is for storage of the Medical...
# F2020050914  DHS /HSI/INTEL has a requirement on a sole sou...
# F2020050991  The proposed procurement action is meant to sa...
# F2020051041  The contractor shall provide services to suppo...
